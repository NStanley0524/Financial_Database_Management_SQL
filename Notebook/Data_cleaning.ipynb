# %%
import pandas as pd
import json

# %%
with open("train_fraud_labels.json","r") as file:
    labels = json.load(file)

labels
# Out:
# {'target': {'10649266': 'No',
#   '23410063': 'No',
#   '9316588': 'No',
#   '12478022': 'No',
#   '9558530': 'No',
#   '12532830': 'No',
#   '19526714': 'No',
#   '9906964': 'No',
#   '13224888': 'No',
#   '13749094': 'No',
#   '12303776': 'No',
#   '19480376': 'No',
#   '11716050': 'No',
#   '20025400': 'No',
#   '7661688': 'No',
#   '16662807': 'No',
#   '21419778': 'No',
#   '18011186': 'No',
#   '23289598': 'No',
#   '11644547': 'No',
#   '23235120': 'No',
#   '19748218': 'No',
#   '8720720': 'No',
#   '18335831': 'No',
#   '18936727': 'No',
#   '15223870': 'No',
#   '12370203': 'No',
#   '17126661': 'No',
#   '22270430': 'No',
#   '18790248': 'No',
#   '20143410': 'No',
#   '9497252': 'No',
#   '17619208': 'No',
#   '11052664': 'No',
#   '14670204': 'No',
#   '17681877': 'No',
#   '22485981': 'No',
#   '22332853': 'No',
#   '16628447': 'No',
#   '7766832': 'No',
#   '7614276': 'No',
#   '14069486': 'No',
#   '13755628': 'No',
#   '17306332': 'No',
#   '19822702': 'No',
# ...

# %%
labels = labels["target"]

df = pd.DataFrame(list(labels.items()),columns=["Transaction_id","Fraud_label"])

df.head()
# Out:
#   Transaction_id Fraud_label
# 0       10649266          No
# 1       23410063          No
# 2        9316588          No
# 3       12478022          No
# 4        9558530          No

# %%
df.to_csv("fraud_labels.csv",index=False)

# %%
with open("mcc_codes.json","r") as file:
    data = json.load(file)

# %%
data
# Out:
# {'5812': 'Eating Places and Restaurants',
#  '5541': 'Service Stations',
#  '7996': 'Amusement Parks, Carnivals, Circuses',
#  '5411': 'Grocery Stores, Supermarkets',
#  '4784': 'Tolls and Bridge Fees',
#  '4900': 'Utilities - Electric, Gas, Water, Sanitary',
#  '5942': 'Book Stores',
#  '5814': 'Fast Food Restaurants',
#  '4829': 'Money Transfer',
#  '5311': 'Department Stores',
#  '5211': 'Lumber and Building Materials',
#  '5310': 'Discount Stores',
#  '3780': 'Computer Network Services',
#  '5499': 'Miscellaneous Food Stores',
#  '4121': 'Taxicabs and Limousines',
#  '5300': 'Wholesale Clubs',
#  '5719': 'Miscellaneous Home Furnishing Stores',
#  '7832': 'Motion Picture Theaters',
#  '5813': 'Drinking Places (Alcoholic Beverages)',
#  '4814': 'Telecommunication Services',
#  '5661': 'Shoe Stores',
#  '5977': 'Cosmetic Stores',
#  '8099': 'Medical Services',
#  '7538': 'Automotive Service Shops',
#  '5912': 'Drug Stores and Pharmacies',
# ...

# %%
df = pd.DataFrame(list(data.items()),columns=["Code","Description"])

df.to_csv("codes.csv",index=False)

# %%
df
# Out:
#      Code                           Description
# 0    5812         Eating Places and Restaurants
# 1    5541                      Service Stations
# 2    7996  Amusement Parks, Carnivals, Circuses
# 3    5411          Grocery Stores, Supermarkets
# 4    4784                 Tolls and Bridge Fees
# ..    ...                                   ...
# 104  7549                       Towing Services
# 105  5941                 Sporting Goods Stores
# 106  5722            Household Appliance Stores
# 107  3009  Fabricated Structural Metal Products
# 108  5733    Music Stores - Musical Instruments
#
# [109 rows x 2 columns]

# %%
df = pd.read_csv("users_data.csv")


df
# Out:
#         id  current_age  retirement_age  birth_year  birth_month  gender  \
# 0      825           53              66        1966           11  Female
# 1     1746           53              68        1966           12  Female
# 2     1718           81              67        1938           11  Female
# 3      708           63              63        1957            1  Female
# 4     1164           43              70        1976            9    Male
# ...    ...          ...             ...         ...          ...     ...
# 1995   986           32              70        1987            7    Male
# 1996  1944           62              65        1957           11  Female
# 1997   185           47              67        1973            1  Female
# 1998  1007           66              60        1954            2    Male
# 1999  1110           21              60        1998           11  Female
#
#                        address  latitude  longitude per_capita_income  \
# ...

# %%
df2 = pd.read_csv("transactions_data.csv")

df2.head()
# Out:
#         id                 date  client_id  card_id   amount  \
# 0  7475327  2010-01-01 00:01:00       1556     2972  $-77.00
# 1  7475328  2010-01-01 00:02:00        561     4575   $14.57
# 2  7475329  2010-01-01 00:02:00       1129      102   $80.00
# 3  7475331  2010-01-01 00:05:00        430     2860  $200.00
# 4  7475332  2010-01-01 00:06:00        848     3915   $46.41
#
#             use_chip  merchant_id merchant_city merchant_state      zip   mcc  \
# 0  Swipe Transaction        59935        Beulah             ND  58523.0  5499
# 1  Swipe Transaction        67570    Bettendorf             IA  52722.0  5311
# 2  Swipe Transaction        27092         Vista             CA  92084.0  4829
# 3  Swipe Transaction        27092   Crown Point             IN  46307.0  4829
# 4  Swipe Transaction        13051       Harwood             MD  20776.0  5813
#
#   errors
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
df2.drop(columns="errors",axis=1,inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13305915 entries, 0 to 13305914
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              int64
#  1   date            object
#  2   client_id       int64
#  3   card_id         int64
#  4   amount          object
#  5   use_chip        object
#  6   merchant_id     int64
#  7   merchant_city   object
#  8   merchant_state  object
#  9   zip             float64
#  10  mcc             int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 1.1+ GB

# %%
df2.isnull().sum()
# Out:
# id                      0
# date                    0
# client_id               0
# card_id                 0
# amount                  0
# use_chip                0
# merchant_id             0
# merchant_city           0
# merchant_state    1563700
# zip               1652706
# mcc                     0
# dtype: int64

# %%
df2[df2.isnull().any(axis=1)]
# Out:
#                 id                 date  client_id  card_id   amount  \
# 7          7475335  2010-01-01 00:14:00       1684     2140   $26.46
# 8          7475336  2010-01-01 00:21:00        335     5131  $261.58
# 18         7475346  2010-01-01 00:34:00        394     4717   $26.04
# 24         7475353  2010-01-01 00:43:00        301     3742   $10.17
# 26         7475356  2010-01-01 00:45:00        566     3439   $16.86
# ...            ...                  ...        ...      ...      ...
# 13305879  23761832  2019-10-31 23:22:00       1556     2972   $17.65
# 13305880  23761833  2019-10-31 23:22:00       1797     5660   $34.81
# 13305888  23761843  2019-10-31 23:33:00       1069     5167   $59.71
# 13305897  23761853  2019-10-31 23:39:00       1422     5696  $694.30
# 13305911  23761869  2019-10-31 23:56:00       1766     2066   $12.80
#
#                     use_chip  merchant_id merchant_city merchant_state  zip  \
# ...

# %%
df2.fillna({"merchant_state":"No State","zip":"No zip"},inplace=True)

# %%
df2.isnull().sum()
# Out:
# id                0
# date              0
# client_id         0
# card_id           0
# amount            0
# use_chip          0
# merchant_id       0
# merchant_city     0
# merchant_state    0
# zip               0
# mcc               0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['id', 'date', 'client_id', 'card_id', 'amount', 'use_chip',
#        'merchant_id', 'merchant_city', 'merchant_state', 'zip', 'mcc'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13305915 entries, 0 to 13305914
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              int64
#  1   date            object
#  2   client_id       int64
#  3   card_id         int64
#  4   amount          object
#  5   use_chip        object
#  6   merchant_id     int64
#  7   merchant_city   object
#  8   merchant_state  object
#  9   zip             object
#  10  mcc             int64
# dtypes: int64(5), object(6)
# memory usage: 1.1+ GB

# %%
df2["amount"] = df2["amount"].str.replace("$","")

# %%
df2["amount"]=df2["amount"].astype(float)

# %%
df2["date"] = pd.to_datetime(df2["date"])

# %%
df2.to_csv("transactions_data.csv",index=False)

# %%
df3 = pd.read_csv("users_data.csv")

df3.head()
# Out:
#      id  current_age  retirement_age  birth_year  birth_month  gender  \
# 0   825           53              66        1966           11  Female
# 1  1746           53              68        1966           12  Female
# 2  1718           81              67        1938           11  Female
# 3   708           63              63        1957            1  Female
# 4  1164           43              70        1976            9    Male
#
#                     address  latitude  longitude per_capita_income  \
# 0             462 Rose Lane     34.15    -117.76            $29278
# 1    3606 Federal Boulevard     40.76     -73.74            $37891
# 2           766 Third Drive     34.02    -117.89            $22681
# 3          3 Madison Street     40.71     -73.99           $163145
# 4  9620 Valley Stream Drive     37.76    -122.44            $53797
#
#   yearly_income total_debt  credit_score  num_credit_cards
# 0        $59696    $127613           787                 5
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2000 non-null   int64
#  1   current_age        2000 non-null   int64
#  2   retirement_age     2000 non-null   int64
#  3   birth_year         2000 non-null   int64
#  4   birth_month        2000 non-null   int64
#  5   gender             2000 non-null   object
#  6   address            2000 non-null   object
#  7   latitude           2000 non-null   float64
#  8   longitude          2000 non-null   float64
#  9   per_capita_income  2000 non-null   object
#  10  yearly_income      2000 non-null   object
#  11  total_debt         2000 non-null   object
#  12  credit_score       2000 non-null   int64
#  13  num_credit_cards   2000 non-null   int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 218.9+ KB

# %%
cols_to_clean = ["per_capita_income","yearly_income","total_debt"]

cols_to_clean
# Out:
# ['per_capita_income', 'yearly_income', 'total_debt']

# %%
df3[cols_to_clean] = df3[cols_to_clean].apply(lambda x:x.str.replace("$","",regex=False).astype(int))

# %%
df3.head()
# Out:
#      id  current_age  retirement_age  birth_year  birth_month  gender  \
# 0   825           53              66        1966           11  Female
# 1  1746           53              68        1966           12  Female
# 2  1718           81              67        1938           11  Female
# 3   708           63              63        1957            1  Female
# 4  1164           43              70        1976            9    Male
#
#                     address  latitude  longitude  per_capita_income  \
# 0             462 Rose Lane     34.15    -117.76              29278
# 1    3606 Federal Boulevard     40.76     -73.74              37891
# 2           766 Third Drive     34.02    -117.89              22681
# 3          3 Madison Street     40.71     -73.99             163145
# 4  9620 Valley Stream Drive     37.76    -122.44              53797
#
#    yearly_income  total_debt  credit_score  num_credit_cards
# 0          59696      127613           787                 5
# ...

# %%
df3.to_csv("users_data.csv",index=False)

# %%
df4 = pd.read_csv("codes.csv")

df4.head()
# Out:
#    Code                           Description
# 0  5812         Eating Places and Restaurants
# 1  5541                      Service Stations
# 2  7996  Amusement Parks, Carnivals, Circuses
# 3  5411          Grocery Stores, Supermarkets
# 4  4784                 Tolls and Bridge Fees

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Code         109 non-null    int64
#  1   Description  109 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 1.8+ KB

# %%
df4 = df4.rename(columns={"Code":"Mcc"})

# %%
df4.to_csv("codes.csv",index=False)

# %%
df5 = pd.read_csv("cards_data.csv")

df5.head()
# Out:
#      id  client_id  card_brand        card_type       card_number  expires  \
# 0  4524        825        Visa            Debit  4344676511950444  12/2022
# 1  2731        825        Visa            Debit  4956965974959986  12/2020
# 2  3701        825        Visa            Debit  4582313478255491  02/2024
# 3    42        825        Visa           Credit  4879494103069057  08/2024
# 4  4659        825  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
#
#    cvv has_chip  num_cards_issued credit_limit acct_open_date  \
# 0  623      YES                 2       $24295        09/2002
# 1  393      YES                 2       $21968        04/2014
# 2  719      YES                 2       $46414        07/2003
# 3  693       NO                 1       $12400        01/2003
# 4   75      YES                 1          $28        09/2008
#
#    year_pin_last_changed card_on_dark_web
# 0                   2008               No
# 1                   2014               No
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6146 entries, 0 to 6145
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     6146 non-null   int64
#  1   client_id              6146 non-null   int64
#  2   card_brand             6146 non-null   object
#  3   card_type              6146 non-null   object
#  4   card_number            6146 non-null   int64
#  5   expires                6146 non-null   object
#  6   cvv                    6146 non-null   int64
#  7   has_chip               6146 non-null   object
#  8   num_cards_issued       6146 non-null   int64
#  9   credit_limit           6146 non-null   object
#  10  acct_open_date         6146 non-null   object
#  11  year_pin_last_changed  6146 non-null   int64
#  12  card_on_dark_web       6146 non-null   object
# dtypes: int64(6), object(7)
# memory usage: 624.3+ KB

# %%
df5.columns
# Out:
# Index(['id', 'client_id', 'card_brand', 'card_type', 'card_number', 'expires',
#        'cvv', 'has_chip', 'num_cards_issued', 'credit_limit', 'acct_open_date',
#        'year_pin_last_changed', 'card_on_dark_web'],
#       dtype='object')

# %%
df5["credit_limit"]=df5["credit_limit"].str.replace("$","",regex=False).astype(int)

# %%
df5["expires"]=pd.to_datetime(df5["expires"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16096\425582191.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df5["expires"]=pd.to_datetime(df5["expires"])

# %%
df5["acct_open_date"]=pd.to_datetime(df5["acct_open_date"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16096\900708195.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df5["acct_open_date"]=pd.to_datetime(df5["acct_open_date"])

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6146 entries, 0 to 6145
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     6146 non-null   int64
#  1   client_id              6146 non-null   int64
#  2   card_brand             6146 non-null   object
#  3   card_type              6146 non-null   object
#  4   card_number            6146 non-null   int64
#  5   expires                6146 non-null   datetime64[ns]
#  6   cvv                    6146 non-null   int64
#  7   has_chip               6146 non-null   object
#  8   num_cards_issued       6146 non-null   int64
#  9   credit_limit           6146 non-null   int64
#  10  acct_open_date         6146 non-null   datetime64[ns]
#  11  year_pin_last_changed  6146 non-null   int64
#  12  card_on_dark_web       6146 non-null   object
# dtypes: datetime64[ns](2), int64(7), object(4)
# memory usage: 624.3+ KB

# %%
df5.to_csv("cards_data.csv",index=False)

# %%
import pandas as pd

merchants = pd.read_csv("codes.csv")

merchants
# Out:
#       Mcc                           Description
# 0    5812         Eating Places and Restaurants
# 1    5541                      Service Stations
# 2    7996  Amusement Parks, Carnivals, Circuses
# 3    5411          Grocery Stores, Supermarkets
# 4    4784                 Tolls and Bridge Fees
# ..    ...                                   ...
# 104  7549                       Towing Services
# 105  5941                 Sporting Goods Stores
# 106  5722            Household Appliance Stores
# 107  3009  Fabricated Structural Metal Products
# 108  5733    Music Stores - Musical Instruments
#
# [109 rows x 2 columns]

# %%
merchant_codes = merchants["Mcc"]

# %%
transacs = pd.read_csv("transactions_data.csv")

transacs_codes = transacs["merchant_id"]

# %%
transacs_codes
# Out:
# 0           59935
# 1           67570
# 2           27092
# 3           27092
# 4           13051
#             ...
# 13305910    86438
# 13305911    39261
# 13305912     2925
# 13305913    46284
# 13305914    24658
# Name: merchant_id, Length: 13305915, dtype: int64

# %%
missing_codes = transacs_codes[~transacs_codes.isin(merchant_codes)]

# %%
missing_codes
# Out:
# 0           59935
# 1           67570
# 2           27092
# 3           27092
# 4           13051
#             ...
# 13305910    86438
# 13305911    39261
# 13305912     2925
# 13305913    46284
# 13305914    24658
# Name: merchant_id, Length: 13296313, dtype: int64
